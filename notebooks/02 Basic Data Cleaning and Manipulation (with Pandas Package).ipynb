# %%
import os
from pathlib import Path
import pandas as pd
#Get Current File Path
full_path = os.getcwd()
#Set Project File Path
ProjectPath = str(Path(full_path).parents[0])

df = pd.read_excel(ProjectPath + '\\data\\raw\\Titanic_Test.xlsx', sheet_name='test')
df.head(1)
# Out:
# C:\Users\cjyi3\AppData\Local\Temp\ipykernel_17080\1302754007.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    PassengerId  Pclass              Name   Sex   Age  SibSp  Parch  Ticket  \
# 0          892       3  Kelly, Mr. James  male  34.5      0      0  330911
#
#      Fare Cabin Embarked
# 0  7.8292   NaN        Q

# %% [markdown]
# ## Keep, Drop, Rearrange, Rename Columns

# %% [markdown]
# ### Keep Specific Columns

# %%
#Keep Columns
df1 = df[['PassengerId','Pclass','Name']]
df1.head(1)
# Out:
#    PassengerId  Pclass              Name
# 0          892       3  Kelly, Mr. James

# %% [markdown]
# ### Drop Specific Columns

# %%
#Drop 1 column
df1 = df.drop('Name',axis=1)
df1.head(1)
# Out:
#    PassengerId  Pclass   Sex   Age  SibSp  Parch  Ticket    Fare Cabin  \
# 0          892       3  male  34.5      0      0  330911  7.8292   NaN
#
#   Embarked
# 0        Q

# %%
#Drop Multiple Columns
df1 = df.drop(['PassengerId','Name'],axis=1)
df1.head(1)
# Out:
#    Pclass   Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0       3  male  34.5      0      0  330911  7.8292   NaN        Q

# %% [markdown]
# ### Rearrange Columns

# %%
#Rearrange Columns
df1 = df[['PassengerId','Name','Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']]
df1.head(1)
# Out:
#    PassengerId              Name  Pclass   Sex   Age  SibSp  Parch  Ticket  \
# 0          892  Kelly, Mr. James       3  male  34.5      0      0  330911
#
#      Fare Cabin Embarked
# 0  7.8292   NaN        Q

# %% [markdown]
# ### Rename Columns

# %%
df1 = df.copy(deep=True)
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#Make a copy
df1 = df.copy(deep=True)
#Rename Columns (order of the columns are important here)
#This method renames all columns
df1.columns = ['PassengerId1','Pclass1','Name1','Sex1','Age1','SibSp1','Parch1','Ticket1','Fare1','Cabin1','Embarked1']
df1.head(1)
# Out:
#    PassengerId1  Pclass1             Name1  Sex1  Age1  SibSp1  Parch1  \
# 0           892        3  Kelly, Mr. James  male  34.5       0       0
#
#   Ticket1   Fare1 Cabin1 Embarked1
# 0  330911  7.8292    NaN         Q

# %%
#To rename only one column/specific columns:
df1.rename(columns={'Name1': 'FullName', 'Age1': 'Age'}, inplace=True)
df1.head(1)
# Out:
#    PassengerId1  Pclass1          FullName  Sex1   Age  SibSp1  Parch1  \
# 0           892        3  Kelly, Mr. James  male  34.5       0       0
#
#   Ticket1   Fare1 Cabin1 Embarked1
# 0  330911  7.8292    NaN         Q

# %% [markdown]
# ## Filtering and Subsets

# %%
#Using .query() for filtering or subset
df1 = df.query('(Sex=="male") & (Age<20)')
print(len(df))
print(len(df1))
df1.head(5)
# Out:
# 418
# 33
#     PassengerId  Pclass                                              Name  \
# 5           897       3                        Svensson, Mr. Johan Cervin
# 21          913       3                         Olsen, Master. Artur Karl
# 35          927       3  Katavelas, Mr. Vassilios (Catavelas Vassilios")"
# 55          947       3                              Rice, Master. Albert
# 60          952       3                                   Dika, Mr. Mirko
#
#      Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 5   male  14.0      0      0     7538   9.2250   NaN        S
# 21  male   9.0      0      1  C 17368   3.1708   NaN        S
# 35  male  18.5      0      0     2682   7.2292   NaN        C
# 55  male  10.0      4      1   382652  29.1250   NaN        Q
# 60  male  17.0      0      0   349232   7.8958   NaN        S

# %%
#Using .loc for filtering or subset
df1 = df.loc[(df['Sex'] == 'male') & (df['Age']<20)]
print(len(df))
print(len(df1))
df1.head(5)
# Out:
# 418
# 33
#     PassengerId  Pclass                                              Name  \
# 5           897       3                        Svensson, Mr. Johan Cervin
# 21          913       3                         Olsen, Master. Artur Karl
# 35          927       3  Katavelas, Mr. Vassilios (Catavelas Vassilios")"
# 55          947       3                              Rice, Master. Albert
# 60          952       3                                   Dika, Mr. Mirko
#
#      Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 5   male  14.0      0      0     7538   9.2250   NaN        S
# 21  male   9.0      0      1  C 17368   3.1708   NaN        S
# 35  male  18.5      0      0     2682   7.2292   NaN        C
# 55  male  10.0      4      1   382652  29.1250   NaN        Q
# 60  male  17.0      0      0   349232   7.8958   NaN        S

# %% [markdown]
# ## Replace values using np.where

# %%
#Make a copy
df1 = df.copy(deep=True)
import numpy as np
#if sex = male, then =M else return original value
df1['Sex'] = np.where(df1['Sex']=="male","M",df1['Sex'])
df1.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James       M
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis       M
# 3          895       3                              Wirz, Mr. Albert       M
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## Substring

# %%
#Make a copy
df1 = df.copy(deep=True)

#Change Sex column from male to M and female to F using substring.
#Substring is a way to extract a part of a string. In this case we just take the first letter in the column 'Sex'.
df1['Sex1'] = df['Sex'].str[:1]
df1[['Sex','Sex1']].head()
# Out:
#       Sex Sex1
# 0    male    m
# 1  female    f
# 2    male    m
# 3    male    m
# 4  female    f

# %% [markdown]
# ## Count # of Rows of dataframe

# %%
len(df)
# Out:
# 418

# %%
#to count how many rows of data where the passanger is male (combining len() and .query()):
len(df.query('Sex=="male"'))
# Out:
# 266

# %% [markdown]
# ## Removing Blankspace

# %% [markdown]
# ### Removing leading and trailing blanks

# %%
#Make a copy
df1 = df.copy(deep=True)

df1['Name1'] = df1['Name'].str.strip()
df1[['Name','Name1']].head(5)
# Out:
#                                            Name  \
# 0                              Kelly, Mr. James
# 1              Wilkes, Mrs. James (Ellen Needs)
# 2                     Myles, Mr. Thomas Francis
# 3                              Wirz, Mr. Albert
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                                           Name1
# 0                              Kelly, Mr. James
# 1              Wilkes, Mrs. James (Ellen Needs)
# 2                     Myles, Mr. Thomas Francis
# 3                              Wirz, Mr. Albert
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)

# %% [markdown]
# ### Remove all space (compress)

# %%
#Make a copy
df1 = df.copy(deep=True)

df1['Name1'] = df1['Name'].replace(' ','')
df1[['Name','Name1']].head(5)
# Out:
#                                            Name  \
# 0                              Kelly, Mr. James
# 1              Wilkes, Mrs. James (Ellen Needs)
# 2                     Myles, Mr. Thomas Francis
# 3                              Wirz, Mr. Albert
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                                           Name1
# 0                              Kelly, Mr. James
# 1              Wilkes, Mrs. James (Ellen Needs)
# 2                     Myles, Mr. Thomas Francis
# 3                              Wirz, Mr. Albert
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)

# %% [markdown]
# ### Remove multiple space and only keep 1 space in between each words

# %%
import pandas as pd

# Sample DataFrame
data = {'Column_with_blanks': ['This   is   a   sentence', 'Another     example', '    More   blanks']}
df1 = pd.DataFrame(data)

print('before removing the blanks:')
for i in df1['Column_with_blanks'].tolist():
    print(i)

#add multiple spaces in between Name Column:
df1['Column_with_blanks'] = df1['Column_with_blanks'].str.replace(r'\s+', ' ', regex=True)
print('-------------')
print('')
print('after removing the blanks:')
for i in df1['Column_with_blanks'].tolist():
    print(i)
# Out:
# before removing the blanks:
# This   is   a   sentence
# Another     example
#     More   blanks
# -------------
#
# after removing the blanks:
# This is a sentence
# Another example
#  More blanks

# %% [markdown]
# ## Capitalize words

# %%
#Make a copy
df1 = df.copy(deep=True)

df1['Name1'] = df1['Name'].str.upper()
df1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
#
#                                           Name1
# 0                              KELLY, MR. JAMES
# 1              WILKES, MRS. JAMES (ELLEN NEEDS)
# ...

# %% [markdown]
# ## Sort tables

# %%
#Make a copy
df1 = df.copy(deep=True)

#Sort Ascending
df1 = df1.sort_values(by=['Pclass'])
df1
# Out:
#      PassengerId  Pclass                                               Name  \
# 208         1100       1                      Rosenbaum, Miss. Edith Louise
# 350         1242       1       Greenfield, Mrs. Leo David (Blanche Strouse)
# 122         1014       1                    Schabert, Mrs. Paul (Emma Mock)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 131         1023       1                          Gracie, Col. Archibald IV
# ..           ...     ...                                                ...
# 165         1057       3         Kink-Heilmann, Mrs. Anton (Luise Heilmann)
# 163         1055       3                                 Pearce, Mr. Ernest
# 161         1053       3                     Touma, Master. Georges Youssef
# 199         1091       3            Rasmussen, Mrs. (Lena Jacobsen Solvang)
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
#Sort Descending
df1 = df1.sort_values(by=['Pclass'], ascending=False)
df1
# Out:
#      PassengerId  Pclass                                           Name  \
# 409         1301       3                      Peacock, Miss. Treasteall
# 289         1181       3                               Ford, Mr. Arthur
# 72           964       3                 Nieminen, Miss. Manta Josefina
# 76           968       3                               Miles, Mr. Frank
# 79           971       3                         Doyle, Miss. Elizabeth
# ..           ...     ...                                            ...
# 403         1295       1                         Carrau, Mr. Jose Pedro
# 12           904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 41           933       1                    Franklin, Mr. Thomas Parham
# 402         1294       1                 Gibson, Miss. Dorothy Winifred
# 208         1100       1                  Rosenbaum, Miss. Edith Louise
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
#Sort by multiple columns
## Sort Ascending for Pclass and descending in PassengerId
df1 = df1.sort_values(by=['Pclass','PassengerId'], ascending=[True,False])
df1
# Out:
#      PassengerId  Pclass                                             Name  \
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 407         1299       1                       Widener, Mr. George Dunton
# 404         1296       1                     Frauenthal, Mr. Isaac Gerald
# 403         1295       1                           Carrau, Mr. Jose Pedro
# ..           ...     ...                                              ...
# 5            897       3                       Svensson, Mr. Johan Cervin
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 3            895       3                                 Wirz, Mr. Albert
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 0            892       3                                 Kelly, Mr. James
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ## Remove Duplicates

# %%
#Make a copy
df1 = df.copy(deep=True)
df1 = df1[['Sex','Pclass']]
df1 = df1.drop_duplicates()
df1
# Out:
#        Sex  Pclass
# 0     male       3
# 1   female       3
# 2     male       2
# 11    male       1
# 12  female       1
# 15  female       2

# %% [markdown]
# ### Keep First and Last Row

# %%
#Make a copy
df1 = df.copy(deep=True)

#Find the first passenger ID that is Pclass = 2 and Sex = female
## First you need to filter for Pclass =2 and Sex = female then sort the dataframe then use .drop_duplicates() to keep the first row
## in the final result, you should have only 1 row. where the data showing the first passengerID who is Pclass 2 and Sex = female
df1 = df1.query('Pclass==2 & Sex =="female"').sort_values(by=['PassengerId'], ascending=[True])
df1 = df1.drop_duplicates(subset=['Pclass', 'Sex'], keep='first')
df1
# Out:
#     PassengerId  Pclass                                           Name  \
# 15          907       2  del Carlo, Mrs. Sebastiano (Argenia Genovesi)
#
#        Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 15  female  24.0      1      0  SC/PARIS 2167  27.7208   NaN        C

# %% [markdown]
# ## Merge tables

# %%
#Make a copy
df1 = df.copy(deep=True)

# Create a new table using Pclass:
Class = pd.DataFrame({'PassClass':[1,2,3,4],
                      'ClassName':['First','Second','Third','Others']})

#merge tables
#left_on and right_on are column names based on the first dataframe and the second dataframe
#how can be left, right, inner, outer join (similar to sql join)
#You may put indicator = True to show which table each row came from.
#Both means there is a match on both tables, left_only indicates there is a match in the left table no matches can be found in the right table, 
#while 'right_only' indicates there is a match in the right table but no match can be found in the right table.
df2 = df1.merge(Class, left_on='Pclass', right_on='PassClass', how='left', indicator=True)
df2.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  PassClass ClassName  \
# 0  34.5      0      0   330911   7.8292   NaN        Q          3     Third
# 1  47.0      1      0   363272   7.0000   NaN        S          3     Third
# 2  62.0      0      0   240276   9.6875   NaN        Q          2    Second
# 3  27.0      0      0   315154   8.6625   NaN        S          3     Third
# 4  22.0      1      1  3101298  12.2875   NaN        S          3     Third
#
#   _merge
# 0   both
# 1   both
# 2   both
# ...

# %% [markdown]
# ### Merge based on index

# %%
df_merge = df1.merge(df2, left_index=True, right_index=True, how='inner')
#how = can be {‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘inner’}

# %% [markdown]
# ### More info on Merge in pandas

# %% [markdown]
# https://stackoverflow.com/questions/53645882/pandas-merging-101

# %% [markdown]
# ## Append/Concatenate tables

# %%
#Make a copy
df1 = df.copy(deep=True)

testdf = pd.DataFrame({'PassengerId':[4000],'Pclass':[4],'Name':['Testing'],'Sex':['male'],'Age':[0],'SibSp':[0],'Parch':[0],'Ticket':['Test'],'Fare':[0.00],'Cabin':['T'],'Embarked':['T']})
testdf

#appending 2 tables
#ignore_index = True means it will create a new index (resetting the index)
df2 = pd.concat([df1, testdf], ignore_index=True)
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
# 418         4000       4                                       Testing
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ## Converting columns to string/int/datetime

# %%
#to change date format from string/numeric date 'YYYYMMDD' to date format
T_df['Date'] = pd.to_datetime(T_df['Date'], format='%Y%m%d', errors='coerce')

# %% [markdown]
# ## Keep alpha and numeric

# %%
testdf = pd.DataFrame({'PassengerId':[4000],'Pclass':[4],'Name':['Testing'],'Sex':['male'],'Age':[0],'SibSp':[0],'Parch':[0],'Ticket':['Test'],'Fare':[0.00],'Cabin':['T//*111'],'Embarked':['T']})

#remove special characters
testdf['Cabin'] = testdf['Cabin'].str.replace(r'[^A-Za-z0-9]', '', regex=True)
testdf
# Out:
#    PassengerId  Pclass     Name   Sex  Age  SibSp  Parch Ticket  Fare Cabin  \
# 0         4000       4  Testing  male    0      0      0   Test   0.0  T111
#
#   Embarked
# 0        T

# %% [markdown]
# ## Common .query() codes

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#Make a copy
df1 = df.copy(deep=True)

#If you have a list of names you want to select, you can use the 'in' operator in the query method.
#List of names to select
GenderList = ['male']

df1.query('Sex in @GenderList')
# Out:
#      PassengerId  Pclass                                             Name  \
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6            898       3                             Connolly, Miss. Kate
# 8            900       3        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12           904       1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ..           ...     ...                                              ...
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
GenderList = ['male']
#if you want to select names not in the list
df1.query('Sex not in @GenderList')

# %% [markdown]
# ## Transpose dataframe

# %%
import numpy as np
import pandas as pd

dataInput = {'MaleNum': [2, 3], 'FemaleNum': [4, 5]}
df = pd.DataFrame(data=dataInput)
df
# Out:
#    MaleNum  FemaleNum
# 0        2          4
# 1        3          5

# %%
df_T = df.T # or you can also use df.transpose()
df_T
# Out:
#            0  1
# MaleNum    2  3
# FemaleNum  4  5

# %% [markdown]
# ## Using .melt() to convert dataframe to long format

# %%
# Sample Data
df = pd.DataFrame({
    'Name': ['Student A', 'Student B', 'Student C'],
    'Math': [90, 85, 95],
    'Science': [80, 89, 92],
    'English': [70, 78, 85]
})

df
# Out:
#         Name  Math  Science  English
# 0  Student A    90       80       70
# 1  Student B    85       89       78
# 2  Student C    95       92       85

# %%
# Use .melt()
# id_vars = specify the columns that you want to keep as columns
# value_vars = specify the columns that you want to melt or making into rows
# var_name = name of the new column that contains the names of the melted columns or the columns that is made into rows
# value_name = name of the new column that contains the values of the melted columns or the columns that is made into rows
df2 = pd.melt(df, id_vars=['Name'], value_vars=['Math', 'Science', 'English'], 
                    var_name='Subject', value_name='Score')
df2
# Out:
#         Name  Subject  Score
# 0  Student A     Math     90
# 1  Student B     Math     85
# 2  Student C     Math     95
# 3  Student A  Science     80
# 4  Student B  Science     89
# 5  Student C  Science     92
# 6  Student A  English     70
# 7  Student B  English     78
# 8  Student C  English     85

# %% [markdown]
# ## Adding Leading 0s to a column

# %%
df1 = df.copy(deep=True)
# add leading 0s to the PassengerId column in total make it 6 digits
df1['PassengerId'] = df1['PassengerId'].apply(lambda x: '{0:0>6}'.format(x))
df1.head(1)
# Out:
#   PassengerId  Pclass              Name   Sex   Age  SibSp  Parch  Ticket  \
# 0      000892       3  Kelly, Mr. James  male  34.5      0      0  330911
#
#      Fare Cabin Embarked
# 0  7.8292   NaN        Q

# %%
df1 = df.copy(deep=True)
#another method to add leading 0s
##to convert int to string then add leading 0
df1['PassengerId'] = df1['PassengerId'].astype(str).str.zfill(6)
df1.head(1)
# Out:
#   PassengerId  Pclass              Name   Sex   Age  SibSp  Parch  Ticket  \
# 0      000892       3  Kelly, Mr. James  male  34.5      0      0  330911
#
#      Fare Cabin Embarked
# 0  7.8292   NaN        Q

# %% [markdown]
# ## Random Sampling

# %% [markdown]
# ### Randomly select based on percentage

# %%
#select 50% of data
#random_state = 1, where 1 is the seed value, which ensures that the same sample will be selected (where the result is reproducible)
df1 = df.sample(frac=0.5, random_state=1)
df1.head(1)
# Out:
#      PassengerId  Pclass                  Name   Sex  Age  SibSp  Parch  \
# 358         1250       3  O'Keefe, Mr. Patrick  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked
# 358  368402  7.75   NaN        Q

# %% [markdown]
# ### Randomly select based on number of rows

# %%
#where n = 10 means select 10 rows
#random_state = 1, where 1 is the seed value, which ensures that the same sample will be selected (where the result is reproducible)
df1 = df.sample(n=10, random_state=1)
df1.head(1)
# Out:
#      PassengerId  Pclass                  Name   Sex  Age  SibSp  Parch  \
# 358         1250       3  O'Keefe, Mr. Patrick  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked
# 358  368402  7.75   NaN        Q

# %% [markdown]
# ## If...Then...Create New column based on conditions

# %% [markdown]
# ### If exact match

# %%
# if Col1 = A then create Col2 where Col2 value is A2.
# if Col1 = B then create Col2 where Col2 value is B2.

df.loc[df['COL1'] == "A", 'COL2'] = 'A2'
df.loc[df['COL1'] == "B", 'COL2'] = 'B2'
df.loc[df['COL1'] == "C", 'COL2'] = 'C2'
df.loc[df['COL1'] == "D", 'COL2'] = 'D2'
df.loc[df['COL1'] == "E", 'COL2'] = 'E2'

# %% [markdown]
# ### Using np.where()

# %%
import numpy as np
df['COL2'] == np.where(df['COL1']=="A", "A2",
                       np.where(df['COL1']=="B", "B2",
                                np.where(df['COL1']=="C", "C2",
                                         np.where(df['COL1']=="D", "D2","E2"))))

#This functions just like if(logical_test,[value_if_true],[value_if_false]) in excel

# %%
## You can also use np.where on multiple elements in a list and assign the same function to each element:
## For example if you want to assign A and B of COL1 to A2 in COL2, you may do the following:
Col1List = ['A', 'B']
df['COL2'] == np.where(df['COL1'].isin(Col1List), "A2",
                        np.where(df['COL1']=="C", "C2",
                            np.where(df['COL1']=="D", "D2","E2")))

# %% [markdown]
# ## To Get Specific Information of a dataframe

# %% [markdown]
# ### Data/Column Type

# %%
df1 = df.copy(deep=True)
df1.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Some basic Statistics

# %%
#get the average of Age column
df1['Age'].mean()
# Out:
# 30.272590361445783

# %%
#get the mode of Age column
df1['Age'].mode()
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
#get the median of Age column
df1['Age'].median()
# Out:
# 27.0

# %%
#get the standard deviation of Age column
df1['Age'].std()
# Out:
# 14.181209235624422

# %%
#get sum of column
df1['Fare'].sum()

# %%
#get distinct values (sort first then get unique values)
df1['PassengerId'].sort_values().unique()
# Out:
# array([ 892,  893,  894,  895,  896,  897,  898,  899,  900,  901,  902,
#         903,  904,  905,  906,  907,  908,  909,  910,  911,  912,  913,
#         914,  915,  916,  917,  918,  919,  920,  921,  922,  923,  924,
#         925,  926,  927,  928,  929,  930,  931,  932,  933,  934,  935,
#         936,  937,  938,  939,  940,  941,  942,  943,  944,  945,  946,
#         947,  948,  949,  950,  951,  952,  953,  954,  955,  956,  957,
#         958,  959,  960,  961,  962,  963,  964,  965,  966,  967,  968,
#         969,  970,  971,  972,  973,  974,  975,  976,  977,  978,  979,
#         980,  981,  982,  983,  984,  985,  986,  987,  988,  989,  990,
#         991,  992,  993,  994,  995,  996,  997,  998,  999, 1000, 1001,
#        1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012,
#        1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023,
#        1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034,
# ...

# %%
#get distinct count use .unique()
print(len(df1['PassengerId'].unique())) 

#or use .value_counts()
print(len(df1['PassengerId'].value_counts()))
# Out:
# 418
# 418
